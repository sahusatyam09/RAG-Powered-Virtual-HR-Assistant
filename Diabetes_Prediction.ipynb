# %% [markdown]
# <a href="https://colab.research.google.com/github/sahusatyam09/RAG-Powered-Virtual-HR-Assistant/blob/main/Diabetes_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data collection and analysis
#
# PIMA Diabetes Dataset

# %%
diabetes_dataset = pd.read_csv('/content/diabetes.csv')

# %%
#printing the frist five rows of the dataset
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#number of rows and coloums in this dataset
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
#getting the statstical measure of the data
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# 0 --> Non-Diabetes
#
# 1 --> Diabetes

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
#seperating the data and levels
X = diabetes_dataset.drop(columns = 'Outcome', axis=1)
Y = diabetes_dataset['Outcome']

# %%
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Data standarize

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
scaler.fit(X)
standarized_data = scaler.transform(X)

# %%
print(standarized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X = standarized_data
Y = diabetes_dataset['Outcome']

# %%
print(X)
print(Y)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Train Test split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2 )

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# Training the model

# %%
classifier = svm.SVC(kernel='linear')

# %%
#Traing the support vector machine classifier
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
 #Accuracy of the traing data
 X_train_prediction = classifier.predict(X_train)
 training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7866449511400652

# %%
#Accuracy of the test data
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)

# %%
print('Accuracy score of the training data : ', test_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7727272727272727

# %% [markdown]
# Makeing a Predective System

# %%
input_data = (4,110,92,0,0,37.6,0.191,30)

#changing the input numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshape the array aswe are predecting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

#standarized the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)

if (prediction[0] == 0):
  print('The person is non diabetic')
else:
  print('The person is diabetic')
# Out:
# [[ 0.04601433 -0.34096773  1.18359575 -1.28821221 -0.69289057  0.71168975
#   -0.84827977 -0.27575966]]
# [0]
# The person is non diabetic
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 124.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 129.2 MB/s eta 0:00:00
# ...

# %%
# !pip install streamlit pyngrok

# %%
# %%writefile app.py
import streamlit as st
import numpy as np

# Page settings
st.set_page_config(page_title="Doctoral Diabetes Checker", page_icon="🩺", layout="centered")

# Custom CSS for background and style
st.markdown("""
    <style>
    body {
        background: linear-gradient(135deg, #cceeff, #e6f7ff);
        color: #003366;
        font-family: 'Arial', sans-serif;
    }
    .stButton>button {
        background-color: #0066cc;
        color: white;
        border-radius: 12px;
        padding: 0.6em 1.2em;
        font-size: 16px;
        transition: 0.3s;
    }
    .stButton>button:hover {
        background-color: #004080;
        transform: scale(1.05);
    }
    .result-box {
        padding: 15px;
        border-radius: 12px;
        font-size: 18px;
        text-align: center;
    }
    </style>
""", unsafe_allow_html=True)

# Title and intro
st.title("🩺 Doctoral Diabetes Prediction Platform")
st.markdown("### Welcome! Enter patient details below to check diabetes risk.")

# Input fields
pregnancies = st.number_input("Pregnancies", min_value=0, max_value=20)
glucose = st.number_input("Glucose Level", min_value=0)
bp = st.number_input("Blood Pressure", min_value=0)
skin = st.number_input("Skin Thickness", min_value=0)
insulin = st.number_input("Insulin", min_value=0)
bmi = st.number_input("BMI", min_value=0.0)
dpf = st.number_input("Diabetes Pedigree Function", min_value=0.0)
age = st.number_input("Age", min_value=0)

# Prediction button
if st.button("🔍 Predict"):
    if glucose > 125 or bmi > 30:
        st.error("⚠️ Result: High chance of Diabetes — please consult a doctor.")
    else:
        st.success("✅ Result: Low chance of Diabetes — stay healthy! 🎉")
# Out:
# Writing app.py

# %%
# !pip install streamlit pyngrok

# %%
from pyngrok import ngrok
ngrok.kill()  # Kill previous tunnels

# Kill any old Streamlit processes
# !kill $(ps aux | grep streamlit | awk '{print $2}')
# Out:
# ^C

# %%
# !ngrok config add-authtoken 31vPCRRKaRTwQwv5nRgGaIxL2M5_ttdePNnC69JyiDBRSjme
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok

# Open ngrok tunnel
public_url = ngrok.connect(8501)
print("👉 Open this URL to access your app:", public_url)

# Start Streamlit
# !streamlit run app.py --server.port 8501 &
# Out:
# 👉 Open this URL to access your app: NgrokTunnel: "https://76deb5a8332f.ngrok-free.app" -> "http://localhost:8501"
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.87.189.54:8501
# WARNING:pyngrok.process.ngrok:t=2025-08-28T17:55:07+0000 lvl=warn msg="failed to check for update" obj=updater err="Post \"https://update.equinox.io/check\": context deadline exceeded"
